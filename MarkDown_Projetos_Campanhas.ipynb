# %% [markdown]
# # 📊 Análise de Campanhas de Marketing – Power BI Dashboard
#
# ## 🎯 Objetivo do Projeto
# Criar um painel interativo em **Power BI** para avaliar o desempenho das campanhas de marketing do último trimestre (Q4).
# O foco foi identificar quais canais trouxeram o melhor **retorno sobre investimento (ROI)** e otimizar o orçamento para o próximo ciclo.
#
# ---
#
# ## 🧠 Contexto
# A equipe de marketing precisava consolidar os resultados de campanhas executadas em diferentes canais — **Google Ads**, **Meta Ads**, **E-mail Marketing** e **tráfego orgânico** — para entender onde o investimento estava gerando mais valor.
#
# O desafio era unificar essas informações e criar um **dashboard dinâmico e intuitivo**, permitindo visualizar o desempenho de cada campanha individualmente.
#
# ---
#
# ## ⚙️ Etapas do Projeto
#
# ### 🗂️ Coleta e Preparação de Dados
# - Base de dados simulada em formato `.csv` (contendo métricas de campanhas).
# - Limpeza e padronização de dados no **Power Query**.
# - Criação de colunas calculadas: **CTR**, **CPC**, **CPA**, **ROI**.
#
# ### 📊 Modelagem e Visualização
# - Construção de KPIs principais no Power BI.
# - Dashboard com filtros por canal e campanha.
# - Visualizações: gráfico de barras comparativo, indicadores de performance e área de insights textuais.
#
# ### 🔍 Interatividade
# - Filtros dinâmicos por campanha.
# - Campos calculados com **DAX** para métricas de marketing.
# - Exibição individual dos resultados ao clicar em cada campanha.
#
# ---
#
# ## 📈 Principais Insights
# - **Promoção de Fim de Ano** teve ROI de **650%**, sendo a campanha mais eficiente.
# - **Natal Social** apresentou ROI **266% superior à média** e custo-benefício elevado.
# - **Black Friday Search** teve o maior volume de impressões, mas também o custo mais alto.
# - **Retargeting Display** demonstrou ROI abaixo da média, sugerindo baixa eficiência.
# - **Campanhas orgânicas** geraram tráfego relevante **sem custo**, reforçando a importância do SEO.
#
# ---
#
# ## 💡 Recomendações
# - Reforçar o investimento nas campanhas **Natal Social** e **Promoção de Fim de Ano**.
# - Reduzir o orçamento destinado à campanha **Retargeting Display**.
# - Manter a estratégia de **SEO e conteúdo orgânico** para captação de tráfego gratuito.
#
# ---
#
# ## 🧰 Ferramentas e Habilidades
# - **Ferramentas:** Power BI, Power Query, DAX, Excel
# - **Habilidades:** Análise de marketing, storytelling visual, modelagem de dados, métricas de performance (ROI, CTR, CPA)
#
# ---
#
# ## 🧩 Resultados
# O dashboard final permitiu visualizar rapidamente:
# - O desempenho de cada canal e campanha.
# - As métricas de eficiência financeira e de engajamento.
# - Os pontos fortes e fracos de cada estratégia de marketing.
#
# O painel foi desenvolvido com foco em **clareza visual**, **comparabilidade** e **comunicação executiva** — características essenciais em relatórios de BI corporativos.
#
# ---
#
# ## 📸 Visualização
# ![Dashboard de Campanhas de Marketing](dashboard_campanhas.png)
# > O relatório é totalmente interativo — ao clicar em cada campanha, os dados e insights se atualizam automaticamente.
#
# ---
#
# ## 🧭 Aprendizados
# Este projeto me ajudou a:
# - Estruturar uma análise de ponta a ponta: da modelagem ao insight.
# - Aplicar conceitos de **data storytelling** e **design de dashboards executivos**.
# - Entender como métricas de marketing se conectam a decisões de negócio.
#
# ---
#
# ## 📂 Arquivos do Projeto
# - `campanhas_marketing_Q4.csv` → Base de dados utilizada
# - `relatório_marketing.pbix` → Arquivo do Power BI
# - `dashboard_campanhas.png` → Print principal do painel
#
# ---
#
# ## ✨ Próximos Passos
# - Adicionar uma análise temporal (evolução do ROI ao longo dos meses).
# - Criar versão pública do dashboard no **Power BI Service**.
# - Incluir cálculo automatizado de **margem de contribuição por campanha**.
#
# ---
#
# 📅 Desenvolvido em: 11 de Novembro de 2025¶
# 👨‍💻 Autor: [Jatanael Guilherme]
# 📧 Contato: jata.dev1976@gmail.com
# 📎 Repositório: [https://github.com/JataGuiz]
# ---
